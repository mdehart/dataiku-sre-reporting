# %%
import requests
import json
from datetime import datetime

PD_API_KEY = "u+xqRscqCG91yXoHxL3g"
SUPPORT_SERVICE_ID = "P2OE4T3", "PWVQZNH"

def fetch_support_escalations():
    url = "https://api.pagerduty.com/incidents"
    headers = {
    "Accept": "application/vnd.pagerduty+json;version=2",
    "Authorization": f"Token token=u+xqRscqCG91yXoHxL3g"
}

    params = {
        "escalation_policy_ids[]": ["P2OE4T3", "PWVQZNH"], 
        "statuses[]": ["triggered", "acknowledged", "resolved"],
        "limit": 10,
        "sort_by": "created_at:desc",
        "total": True
    }
    
    response = requests.get(url, headers=headers, params=params)
    
    if response.status_code != 200:
        print(f"Error: {response.status_code} - {response.text}")
        return

    incidents = response.json().get('incidents', [])

    # --- PRETTY FORMATTING ---
    print(f"{'#' * 30}")
    print(f"{'LAST 10 SUPPORT ESCALATIONS':^30}")
    print(f"{'#' * 30}\n")

    if not incidents:
        print("No recent escalations found for this service.")
        return

    for i, inc in enumerate(incidents, 1):
        num = inc.get('incident_number')
        status = inc.get('status').upper()
        # Clean up the timestamp
        raw_date = inc.get('created_at')
        clean_date = datetime.strptime(raw_date, "%Y-%m-%dT%H:%M:%SZ").strftime("%b %d, %H:%M")
        title = inc.get('title')
        
        # Pretty Print Block
        print(f"{i}. [{status}] Incident #{num}")
        print(f"   Created: {clean_date}")
        print(f"   Summary: {title}")
        print(f"   Link:    {inc.get('html_url')}")
        print("-" * 50)

fetch_support_escalations()
